# %% [markdown]
# <a href="https://colab.research.google.com/github/shyam2205/Abook/blob/master/Week1_Day1_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Python Programming Day 1
# #### GGI5A - Week1_Day1
# * Data Types

# %%
# integer
a = 5
print (a)
type(a)
# Out:
# 5
# int

# %%
# Float
b = 5.5
print(b)
type(b)
# Out:
# 5.5
# float

# %%
#String
c = 'Shyam'
print(c)
type(c)
# Out:
# Shyam
# str

# %%
# List with same data types

int_list1 = [2,5,7]
print(int_list1)
type(int_list1)
# Out:
# [2, 5, 7]
# list

# %%
# List with Mixed Data Types

mixed_list = ['Shyam', 42, 'Bachelors', 'Coding Background: No', 5.5]
print(mixed_list)
type(mixed_list)
# Out:
# ['Shyam', 42, 'Bachelors', 'Coding Background: No', 5.5]
# list

# %%
# Modifying List using Indexing
mixed_list[2] = 'MSC'
print(mixed_list)
# Out:
# ['Shyam', 42, 'MSC', 'Coding Background: No', 5.5]

# %%
# List Comparison
list1 = [1,2,3]
list2 = [3,2,1]
list1 == list2
# Out:
# False

# %%
# Duplicate Values in list
list1 = [1,2,2,3,4,5,4,5]
print(list1)
# Out:
# [1, 2, 2, 3, 4, 5, 4, 5]

# %%
# Accessing Elements in the list
my_list = [10, 20, 30, 40, 50]
my_list
print (my_list[2])
print(my_list[4])
# Out:
# 30
# 50

# %%
# Slicing
slice = [10, 20, 30, 40, 50, 60]
slice[0:2]
slice[1:3]
slice[2:]
slice[::-1]
# Out:
# [60, 50, 40, 30, 20, 10]

# %%
#Append()
list_append=[1, 2, 3]
list_append.append(4)
list_append
# Out:
# [1, 2, 3, 4]

# %%
# insert()
ilist = [1, 2, 3, 4]
ilist.insert(2, 3.5)
ilist
# Out:
# [1, 2, 3.5, 3, 4]

# %%
#extend()
elist = [1, 2, 3, 4]
elist.extend(5, 6, 7)
elist
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3947572368.py in <cell line: 0>()
#       1 #extend()
#       2 elist = [1, 2, 3, 4]
# ----> 3 elist.extend(5, 6, 7)
#       4 elist
#
# TypeError: list.extend() takes exactly one argument (3 given)

# %%
rem_list = [1, 2, 3, 4, 5, 6]
rem_list.remove(3)
rem_list
# Out:
# [1, 2, 4, 5, 6]

# %%
rem_list.pop(2)
rem_list
# Out:
# [1, 2, 6]

# %%
rem_list.clear()
rem_list
# Out:
# []

# %%
# Loopig through a list
my_list = [10, 20, 30, 40, 50]
for element in my_list:
    print(element)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
# Squaring the values in list using for loop
my_list = [1, 2, 3, 4, 5]
squared_list = []
for num in my_list:
    squared_list.append(num ** 2)
squared_list
# Out:
# [1, 4, 9, 16, 25]

# %%
# Squaring the values in list using for loop
mylist = [1, 2, 3]
for i in mylist:
  c = i ** 2
  print (c)
# Out:
# 1
# 4
# 9

# %%
# Printing the String Vertically
string = 'Shyam'
for char in string:
  print(char)
# Out:
# S
# h
# y
# a
# m

# %%
# Sorting List in Ascending
mylist.sort()
mylist
# Out:
# [1, 2, 3]

# %%
# Descedning Order
mylist.sort(reverse=True)
mylist
# Out:
# [3, 2, 1]

# %%
# reverse a list: reverse()
mylist.reverse() #reverses the current list could be descendig to Ascending vice-versa
mylist
# Out:
# [3, 2, 1]

# %%
# length()
len(mylist)
# Out:
# 5

# %%
# Maximum Value
mylist = [1, 2, 3, 4, 5]
max(mylist)
# Out:
# 5

# %%
# Minimum Value
min(mylist)
# Out:
# 1

# %%
# Sum ()
sum(mylist)
# Out:
# 15

# %%
# Count ()
mylist.count(2)
# Out:
# 1

# %%
# index ()
mylist.index(3)
# Out:
# 2

# %%
# Tuple example
my_tuple = (1, 2, 3, 4, 5)
my_tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
# Duplicates in Tuple
t1 = (1, 2, 2, 3, 4, 5)
t1
# Out:
# (1, 2, 2, 3, 4, 5)

# %%
# Tuple with Mixed Data Types
t2 = ('Shyam', 42, 'Bachelors', 'Coding Background: No', 5.5)
t2
type(t2)
# Out:
# tuple

# %%
# Tuple without brackets
t3 = 1, 2, 3, 4, 5
t3 # By default value is returned in tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
# Example for Immutable Tuple
my_tuple = (1, 2, 3, 4, 5)
my_tuple[2] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2108658487.py in <cell line: 0>()
#       1 # Example for Immutable Tuple
#       2 my_tuple = (1, 2, 3, 4, 5)
# ----> 3 my_tuple[2] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
# How to change Values in Tuple
my_tuple = (1, 2, 3, 4, 5)
my_list = list(my_tuple)
my_list[2] = 10
my_tuple = tuple(my_list)
my_tuple
# Out:
# (1, 2, 10, 4, 5)

# %%
# Indexing in a Tuple
my_tuple = (10, 20, 30, 40, 50)
my_tuple[3]
# Out:
# 40

# %%
# slicing in tuple
my_tuple = (10, 20, 30, 40, 50)
my_tuple[2:5]
# Out:
# (30, 40, 50)

# %%
# Concatente 2 tuples
tuple1 = (1, 2, 3)
tuple2 = (4, 5, 6)
tuple3 = tuple1 + tuple2
tuple3
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
# to find how many times 2 is there in the tuple
my_tuple = (1, 2, 3, 2, 4, 2, 5)
my_tuple.count(2)
# Out:
# 3

# %%
# Loop through and create a Square of each element
my_tuple = (1, 2, 3, 4, 5)
squared_tuple = tuple(num ** 2 for num in my_tuple)
squared_tuple
# Out:
# (1, 4, 9, 16, 25)

# %%
# Loop through and create a Square of each element
my_tuple = (1, 2, 3, 4, 5)
squared_tuple = []
for num in my_tuple:
    squared_tuple.append(num ** 2)
tuple(squared_tuple)
# Out:
# (1, 4, 9, 16, 25)

# %%
# Dictionary
my_dict = {'name': 'Shyam', 'age': 42, 'major': 'Bachelors'}
my_dict
# Out:
# {'name': 'Shyam', 'age': 42, 'major': 'Bachelors'}

# %%
# Dictionary self without AI
my_dict1 = {'Name' : 'Shyam', 'Age' : 43, 'Major': 'Bachelors'}
my_dict1
type(my_dict1)
# Out:
# dict

# %%
# Access Age Key in Dictionay
my_dict1['Age']
# Out:
# 43

# %%
# Access elements in Dictionary
my_dict1['Name']
# Out:
# 'Shyam'

# %%
# Change the value of Age
my_dict1['Age'] = 44
my_dict1
# Out:
# {'Name': 'Shyam', 'Age': 44, 'Major': 'Bachelors'}

# %%
# Adding a new Key:Value pair called Country:India
my_dict1['Country'] = 'India'
my_dict1
# Out:
# {'Name': 'Shyam', 'Age': 44, 'Major': 'Bachelors', 'Country': 'India'}

# %%
# pop the coutry Key: value pair
my_dict1.pop('Country')
my_dict1
# Out:
# {'Name': 'Shyam', 'Age': 44, 'Major': 'Bachelors'}

# %%
# popitem
my_dict1.popitem()
my_dict1
# Out:
# {'Name': 'Shyam', 'Age': 44}

# %%
# Update the Value in a dictionary
my_dict1.update({'Age': 45})
my_dict1
# Out:
# {'Name': 'Shyam', 'Age': 45}

# %%
# Updating dict1 with dict 2
dict1 = {'a': 1, 'b': 2}
dict2 = {'b': 3, 'c': 4}
dict1.update(dict2) # Dict1 is updated with Dict2
dict1 # Will have only b value in dict2 (unique value)
# Out:
# {'a': 1, 'b': 3, 'c': 4}

# %%
# Looping in a Dictionary
my_dict = {'name': 'Shyam', 'age': 42, 'major': 'Bachelors'}
for key, value in my_dict.items():
    print(key, value)
# Out:
# name Shyam
# age 42
# major Bachelors

# %%
for key in my_dict.keys():
  print(key)
# Out:
# name
# age
# major

# %%
for value in my_dict.values():
  print(value)
# Out:
# Shyam
# 42
# Bachelors

# %%
for i in my_dict.items():
  print(i)
# Out:
# ('name', 'Shyam')
# ('age', 42)
# ('major', 'Bachelors')

# %%
# Copying the Dictionary in to a new one
my_dict = {'name': 'Shyam', 'age': 42, 'major': 'Bachelors'}
new_dict = my_dict.copy()
new_dict
# Out:
# {'name': 'Shyam', 'age': 42, 'major': 'Bachelors'}

# %%
# Creating a Set
my_set = {1, 2, 3, 4, 5}
my_set
# Out:
# {1, 2, 3, 4, 5}

# %%
# Having 1, True and False in a Set
my_set1 = {1, True, False}
my_set1 # True is read as 1
# Out:
# {False, 1}

# %%
my_set[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1306209179.py in <cell line: 0>()
# ----> 1 my_set[2]
#
# TypeError: 'set' object is not subscriptable

# %%
# Adding Elements to a Set
my_set = {1, 2, 3}
my_set.add(4)
my_set
# Out:
# {1, 2, 3, 4}

# %%
# Update a SET
my_set = {1, 2, 3}
my_set.update([4, 5, 6])
my_set
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
# remove() in Set
my_set = {1, 2, 3, 4, 5}
my_set.remove(3)
my_set
# Out:
# {1, 2, 4, 5}

# %%
# pop()
my_set = {1, 2, 3, 4, 5}
my_set.pop() # Removes a Random Value, most of the times last element
my_set
# Out:
# {2, 3, 4, 5}

# %%
# clear()
my_set = {1, 2, 3, 4, 5}
my_set.clear()
my_set
# Out:
# set()
